# %% [markdown]
# #  Introduction
#
# ## About this dataset
#
# For each dataset, the fields are:
# * Time
# * Ls
# * LT
# * Tsurf: surface temperature (in Kelvin)
# * Psurf: surface pressure (in Pascals)
# * CO2ice: Surface carbon dioxide ice (in kg per metre squared)
# * cloud: water ice column (in opacity)
# * vapour: water vapour column (in kg per metre squared)
# * u_wind: Zonal wind (west-east) (metres per second)
# * v_wind: Meridional wind (north-south) (metres per second)
# * dust: dust column (in opacity)
# * temp: atmospheric temperature at a height of abour 2.5 km (in Kelvin)
#
# ## About this notebook
# The purpose of this notebook is to explore this dataset in terms of different visualisations. The lux library (https://github.com/lux-org/lux) is used for visualisation purpose.
#
# Kindly visit (https://lux-api.readthedocs.io/en/latest/source/getting_started/installation.html) to install the jupyter notebook widget to enable lux on the notebook if Lux doesn't function properly in your local notebook.
#
# ### Limitations
#
# No optimisation for memory, runtime, or readability.

# %% [markdown]
# ## Install and import required libraries

# %%
# !pip install lux-api==0.5.1
# !jupyter nbextension install --py luxwidget
# !jupyter nbextension enable --py luxwidget
import pandas as pd
# Out:
# Requirement already satisfied: lux-api==0.5.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (0.5.1)
# Requirement already satisfied: scipy>=1.3.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (1.11.1)
# Requirement already satisfied: altair>=4.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (5.1.2)
# Requirement already satisfied: numpy>=1.16.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (1.24.3)
# Requirement already satisfied: pandas in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (2.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (1.3.0)
# Requirement already satisfied: matplotlib>=3.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (3.7.3)
# Requirement already satisfied: lux-widget>=0.1.4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (0.1.11)
# Requirement already satisfied: autopep8>=1.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (2.0.4)
# Requirement already satisfied: iso3166 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (2.1.1)
# Requirement already satisfied: psutil>=5.9.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (5.9.5)
# Requirement already satisfied: sh in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-api==0.5.1) (2.0.6)
# Requirement already satisfied: jinja2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from altair>=4.0.0->lux-api==0.5.1) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from altair>=4.0.0->lux-api==0.5.1) (4.19.0)
# Requirement already satisfied: packaging in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from altair>=4.0.0->lux-api==0.5.1) (23.1)
# Requirement already satisfied: toolz in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from altair>=4.0.0->lux-api==0.5.1) (0.12.0)
# Requirement already satisfied: pycodestyle>=2.10.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from autopep8>=1.5->lux-api==0.5.1) (2.11.1)
# Requirement already satisfied: notebook>=4.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-widget>=0.1.4->lux-api==0.5.1) (7.0.3)
# Requirement already satisfied: ipywidgets>=7.5.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from lux-widget>=0.1.4->lux-api==0.5.1) (8.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (9.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from matplotlib>=3.0.0->lux-api==0.5.1) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from pandas->lux-api==0.5.1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from pandas->lux-api==0.5.1) (2023.3)
# Requirement already satisfied: joblib>=1.1.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from scikit-learn>=0.22->lux-api==0.5.1) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from scikit-learn>=0.22->lux-api==0.5.1) (2.2.0)
# Requirement already satisfied: comm>=0.1.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.1.4)
# Requirement already satisfied: ipython>=6.1.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (8.15.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (3.0.8)
# Requirement already satisfied: attrs>=22.2.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (0.10.2)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.7.3)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.24.0)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (4.0.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (6.3.3)
# Requirement already satisfied: six>=1.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->lux-api==0.5.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jinja2->altair>=4.0.0->lux-api==0.5.1) (2.1.2)
# Requirement already satisfied: backcall in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.2.0)
# Requirement already satisfied: decorator in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.19.0)
# Requirement already satisfied: matplotlib-inline in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.1.6)
# Requirement already satisfied: pickleshare in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.16.1)
# Requirement already satisfied: stack-data in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (4.8.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (4.0.0)
# Requirement already satisfied: argon2-cffi in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (23.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (8.3.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (5.3.1)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.7.0)
# Requirement already satisfied: jupyter-server-terminals in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (7.8.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (5.9.2)
# Requirement already satisfied: overrides in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.17.1)
# Requirement already satisfied: pyzmq>=24 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (25.1.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.17.1)
# Requirement already satisfied: websocket-client in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.0.4)
# Requirement already satisfied: ipykernel in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (6.25.2)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab<5,>=4.0.2->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.9.14)
# Requirement already satisfied: requests>=2.28 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.28.1)
# Requirement already satisfied: idna>=2.8 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (6.0.0)
# Requirement already satisfied: defusedxml in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.2.1)
# Requirement already satisfied: fastjsonschema in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.18.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.2.6)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.22.1->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2022.12.7)
# Requirement already satisfied: argon2-cffi-bindings in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.7.0)
# Requirement already satisfied: nest-asyncio in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from ipykernel->jupyterlab<5,>=4.0.2->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.5.7)
# Requirement already satisfied: executing>=1.2.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.4.0)
# Requirement already satisfied: pure-eval in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.2.2)
# Requirement already satisfied: webencodings in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (0.5.1)
# Requirement already satisfied: fqdn in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (1.5.1)
# Requirement already satisfied: isoduration in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (2.4)
# Requirement already satisfied: uri-template in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.5)
# Requirement already satisfied: pycparser in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=4.0.0->lux-widget>=0.1.4->lux-api==0.5.1) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/ubuntu/miniconda3/envs/OpenMars/lib/python3.11/site-packages (from isoduration->jsonschema>=3.0->altair>=4.0.0->lux-api==0.5.1) (1.2.3)
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.
# usage: jupyter [-h] [--version] [--config-dir] [--data-dir] [--runtime-dir]
#                [--paths] [--json] [--debug]
#                [subcommand]
#
# Jupyter: Interactive Computing
#
# positional arguments:
#   subcommand     the subcommand to launch
#
# options:
#   -h, --help     show this help message and exit
#   --version      show the versions of core jupyter packages and exit
#   --config-dir   show Jupyter config dir
#   --data-dir     show Jupyter data dir
#   --runtime-dir  show Jupyter runtime dir
#   --paths        show all Jupyter paths. Add --json for machine-readable
#                  format.
#   --json         output paths as machine-readable json
#   --debug        output debug information about paths
#
# Available subcommands: console dejavu events execute kernel kernelspec lab
# labextension labhub migrate nbconvert notebook qtconsole run server
# troubleshoot trust
#
# Jupyter command `jupyter-nbextension` not found.

# %%
df= pd.read_csv('/home/ubuntu/OpenMarsML/data/data_files/insight_openmars_training_time.csv', header=0)
df.head()
# Out:
#                   Time     Ls    LT    Tsurf    Psurf  CO2ice  cloud  vapour  \
# 0  1998-07-15 21:23:39  0.555   9.0  264.042  721.113     0.0  0.092   0.027
# 1  1998-07-15 23:26:53  0.598  11.0  274.736  705.090     0.0  0.145   0.026
# 2  1998-07-16 01:30:07  0.640  13.0  265.939  700.691     0.0  0.105   0.026
# 3  1998-07-16 03:33:21  0.683  15.0  238.624  697.252     0.0  0.134   0.025
# 4  1998-07-16 05:36:35  0.725  17.0  213.634  717.146     0.0  0.139   0.026
#
#    u_wind  v_wind   dust     temp
# 0  -7.451   8.604  0.428  179.686
# 1  -7.053   4.934  0.427  174.502
# 2  -6.825  -0.063  0.427  173.429
# 3  -5.373  -4.048  0.426  173.556
# 4  -3.899  -3.133  0.426  174.789

# %% [markdown]
# ## Begin with code snippets

# %%
#inmport data
df.drop(['Ls','LT','CO2ice'],axis=1,inplace=True)
target = df['Psurf']
df.drop(labels=['Psurf'], axis=1,inplace = True)
df.insert(1, 'Psurf', target)

df['Time']= pd.to_datetime(df['Time'])
df
# Out:
#                      Time    Psurf    Tsurf  cloud  vapour  u_wind  v_wind  \
# 0     1998-07-15 21:23:39  721.113  264.042  0.092   0.027  -7.451   8.604
# 1     1998-07-15 23:26:53  705.090  274.736  0.145   0.026  -7.053   4.934
# 2     1998-07-16 01:30:07  700.691  265.939  0.105   0.026  -6.825  -0.063
# 3     1998-07-16 03:33:21  697.252  238.624  0.134   0.025  -5.373  -4.048
# 4     1998-07-16 05:36:35  717.146  213.634  0.139   0.026  -3.899  -3.133
# ...                   ...      ...      ...    ...     ...     ...     ...
# 72191 2015-06-18 04:24:40  730.498  235.054  0.019   0.014   1.868   8.633
# 72192 2015-06-18 06:27:53  730.753  264.949  0.015   0.014  -6.924   6.590
# 72193 2015-06-18 08:31:07  703.987  275.776  0.012   0.014  -4.681   2.727
# 72194 2015-06-18 10:34:21  695.836  266.946  0.012   0.014  -3.277  -5.484
# 72195 2015-06-18 12:37:35  694.349  239.486  0.028   0.014  -2.180  -7.982
#
#         dust     temp
# 0      0.428  179.686
# 1      0.427  174.502
# 2      0.427  173.429
# 3      0.426  173.556
# 4      0.426  174.789
# ...      ...      ...
# 72191  0.388  191.498
# 72192  0.388  187.591
# 72193  0.388  185.172
# 72194  0.388  184.216
# 72195  0.388  183.922
#
# [72196 rows x 9 columns]

# %%
# Display Surface pressure based plot# 
import lux
df.intent = ["Psurf"]
Psurf_viz = df.recommendation['Enhance']
Psurf_viz
# Out:
# /tmp/ipykernel_20401/3183883535.py:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.intent = ["Psurf"]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_20401/3183883535.py in ?()
#       1 # Display Surface pressure based plot#
#       2 import lux
#       3 df.intent = ["Psurf"]
# ----> 4 Psurf_viz = df.recommendation['Enhance']
#       5 Psurf_viz
#
# ~/miniconda3/envs/OpenMars/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6198             and name not in self._accessors
#    6199             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6200         ):
#    6201             return self[name]
# -> 6202         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'recommendation'
